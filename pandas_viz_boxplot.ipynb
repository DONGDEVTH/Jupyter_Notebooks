# %%
import pandas as pd
# %matplotlib inline
pd.__version__
# Out:
# '1.1.3'

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/mpg.csv')
df.sample(10)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 55         dodge    dakota pickup 4wd    5.2  1999    8  manual(m5)   4   11
# 65         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 21     chevrolet   c1500 suburban 2wd    5.7  1999    8    auto(l4)   r   13
# 179       toyota                camry    2.2  1999    4  manual(m5)   f   21
# 35     chevrolet               malibu    3.5  2008    6    auto(l4)   f   18
# 18     chevrolet   c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14
# 77          ford         explorer 4wd    4.0  1999    6    auto(l5)   4   14
# 101        honda                civic    1.6  1999    4  manual(m5)   f   25
# 81          ford         explorer 4wd    4.6  2008    8    auto(l6)   4   13
# 161       subaru         forester awd    2.5  2008    4  manual(m5)   4   20
#
#      hwy fl       class
# 55    17  r      pickup
# 65    12  e      pickup
# 21    17  r         suv
# 179   29  r     midsize
# 35    29  r     midsize
# 18    20  r         suv
# 77    17  r         suv
# 101   32  r  subcompact
# 81    19  r         suv
# 161   27  r         suv

# %%
df.cty.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df[['cty', 'hwy']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df[['cty', 'hwy']].boxplot();

# %%
df.boxplot(column=['cty', 'hwy'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['cty', 'hwy'], by='drv')
# Out:
# array([<AxesSubplot:title={'center':'cty'}, xlabel='drv'>,
#        <AxesSubplot:title={'center':'hwy'}, xlabel='drv'>], dtype=object)

# %%
df.boxplot(column=['cty', 'hwy'], by='drv', grid=False)
# Out:
# array([<AxesSubplot:title={'center':'cty'}, xlabel='drv'>,
#        <AxesSubplot:title={'center':'hwy'}, xlabel='drv'>], dtype=object)

# %%
df.boxplot(column='cty', by=['class', 'drv'])
# Out:
# <AxesSubplot:title={'center':'cty'}, xlabel='[class, drv]'>

# %%
df.boxplot(column='cty', by=['class', 'drv'], rot=90, grid=False)
# Out:
# <AxesSubplot:title={'center':'cty'}, xlabel='[class, drv]'>

# %%
df.boxplot(column='cty', by=['class', 'drv'], vert=False, grid=False);

# %%
df.boxplot(column=['cty','hwy'], by=['class', 'drv'], vert=False, grid=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-737a96b357c2> in <module>
# ----> 1 df.boxplot(column=['cty','hwy'], by=['class', 'drv'], vert=False, grid=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     492 ):
#     493     plot_backend = _get_plot_backend(backend)
# --> 494     return plot_backend.boxplot_frame(
#     495         self,
#     496         column=column,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     378     import matplotlib.pyplot as plt
#     379
# --> 380     ax = boxplot(
#     381         self,
#     382         column=column,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     330         # Prefer array return type for 2-D plots to match the subplot layout
#     331         # https://github.com/pandas-dev/pandas/pull/12216#issuecomment-241175580
# --> 332         result = _grouped_plot_by_column(
#     333             plot_group,
#     334             data,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     209         gp_col = grouped[col]
#     210         keys, values = zip(*gp_col)
# --> 211         re_plotf = plotf(keys, values, ax, **kwargs)
#     212         ax.set_title(col)
#     213         ax.set_xlabel(pprint_thing(by))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in plot_group(keys, values, ax)
#     307             ax.set_xticklabels(keys, rotation=rot)
#     308         else:
# --> 309             ax.set_yticklabels(keys, rotation=rot)
#     310         maybe_color_bp(bp, **kwds)
#     311
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1791         if fontdict is not None:
#    1792             kwargs.update(fontdict)
# -> 1793         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1794
#    1795     @cbook._make_keyword_only("3.2", "minor")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1712             # remove all tick labels, so only error for > 0 ticklabels
#    1713             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1714                 raise ValueError(
#    1715                     "The number of FixedLocator locations"
#    1716                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (24), usually from a call to set_ticks, does not match the number of ticklabels (12).

# %%
df.boxplot(column=['cty', 'hwy'], by=['class', 'drv'], vert=False, grid=False, figsize=(10, 5));
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-76024bdda216> in <module>
# ----> 1 df.boxplot(column=['cty', 'hwy'], by=['class', 'drv'], vert=False, grid=False, figsize=(10, 5));
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     492 ):
#     493     plot_backend = _get_plot_backend(backend)
# --> 494     return plot_backend.boxplot_frame(
#     495         self,
#     496         column=column,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     378     import matplotlib.pyplot as plt
#     379
# --> 380     ax = boxplot(
#     381         self,
#     382         column=column,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     330         # Prefer array return type for 2-D plots to match the subplot layout
#     331         # https://github.com/pandas-dev/pandas/pull/12216#issuecomment-241175580
# --> 332         result = _grouped_plot_by_column(
#     333             plot_group,
#     334             data,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     209         gp_col = grouped[col]
#     210         keys, values = zip(*gp_col)
# --> 211         re_plotf = plotf(keys, values, ax, **kwargs)
#     212         ax.set_title(col)
#     213         ax.set_xlabel(pprint_thing(by))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in plot_group(keys, values, ax)
#     307             ax.set_xticklabels(keys, rotation=rot)
#     308         else:
# --> 309             ax.set_yticklabels(keys, rotation=rot)
#     310         maybe_color_bp(bp, **kwds)
#     311
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1791         if fontdict is not None:
#    1792             kwargs.update(fontdict)
# -> 1793         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1794
#    1795     @cbook._make_keyword_only("3.2", "minor")
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1712             # remove all tick labels, so only error for > 0 ticklabels
#    1713             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1714                 raise ValueError(
#    1715                     "The number of FixedLocator locations"
#    1716                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (24), usually from a call to set_ticks, does not match the number of ticklabels (12).
