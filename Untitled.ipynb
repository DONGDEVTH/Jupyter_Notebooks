# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
>>> dat=pd.read_excel('data/asset.xlsx', nrows=70)
>>> dat
# Out:
#                              Name                          model  \
# 0                        ACC_NOOK                         Lenovo
# 1                          Acc-01         To Be Filled By O.E.M.
# 2                         ACC-TIM  Gigabyte Technology Co., Ltd.
# 3   admin_KML Pool bar the beach1  Gigabyte Technology Co., Ltd.
# 4                      AP-SUNWING  Gigabyte Technology Co., Ltd.
# ..                            ...                            ...
# 65                  pk-bythesea-2                      Dell Inc.
# 66                   pk-bythesea1  Gigabyte Technology Co., Ltd.
# 67                   pk-bythesea3  Gigabyte Technology Co., Ltd.
# 68                PoolBar_Latasca  Gigabyte Technology Co., Ltd.
# 69               PoolBarByThePool  Gigabyte Technology Co., Ltd.
#
#                      displ  year          trans  drv  cyl  hwy   fl
# 0                  R8GLRXG  1988        7515RT5    1    4   20  3GB
# ...

# %%
# %history -t
# Out:
# import pandas as pd
# import numpy as np
# df=pd.read_excel('data/asset.xlsx')
# df=pd.read_excel('data/asset.xlsx', nrows=10)
# df=pd.read_excel('data/asset.xlsx', index_col=0)
# df=pd.read_excel('data/asset.xlsx', index_col=0)
# df=pd.read_excel('data/asset.xlsx', index_col=0)
# df
# df=pd.read_excel('data/asset.xlsx', nrows=10)
# df
# df=pd.read_excel('data/asset.xlsx', nrows=10)
# df
# df.hist()
# import pandas as pd
# import numpy as np
#
# get_ipython().run_line_magic('matplotlib', 'inline')
# df.hist()
# import pandas as pd
# import numpy as np
# get_ipython().run_line_magic('matplotlib', 'inline')
# df=pd.read_excel('data/asset.xlsx', nrows=10)
# df
# df.hist()
# df.hist()
# df.hist()
# df.hist()
# df=pd.read_excel('data/asset.xlsx')
# df
# df=pd.read_excel('data/asset.xlsx')
# df
# df.hist()
# import pandas as pd
# import numpy as np
# get_ipython().run_line_magic('matplotlib', 'inline')
# df=pd.read_excel('data/asset.xlsx')
# df
# df.hist()
# ...

# %%
dat.hist()
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'drv'}>],
#        [<AxesSubplot:title={'center':'cyl'}>,
#         <AxesSubplot:title={'center':'hwy'}>]], dtype=object)

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

>>> dat=pd.read_excel('data/asset.xlsx', nrows=70)
>>> dat

# %history -t

dat.hist()
