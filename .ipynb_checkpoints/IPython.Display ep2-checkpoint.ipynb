# %% [markdown]
# IPython.Display

# %%
from IPython.display import IFrame, YouTubeVideo, SVG, HTML

# %% [markdown]
# # DISPLAY WEB PAGE

# %%
IFrame("https://matplotlib.org/examples/color/named_colors.html", width=800, height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://matplotlib.org/examples/color/named_colors.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
df=pd.read_csv('https://github.com/prasertcbs/tutorial/raw/master/msleep.csv')
df.sample(5)
# Out:
#                       name         genus   vore         order  conservation  \
# 18              Tree hyrax   Dendrohyrax  herbi    Hyracoidea            lc
# 69  Arctic ground squirrel  Spermophilus  herbi      Rodentia            lc
# 77                  Tenrec        Tenrec   omni  Afrosoricida           NaN
# 48                   Sheep          Ovis  herbi  Artiodactyla  domesticated
# 53                  Baboon         Papio   omni      Primates           NaN
#
#     sleep_total  sleep_rem  sleep_cycle  awake  brainwt  bodywt
# 18          5.3        0.5          NaN   18.7   0.0123   2.950
# 69         16.6        NaN          NaN    7.4   0.0057   0.920
# 77         15.6        2.3          NaN    8.4   0.0026   0.900
# 48          3.8        0.6          NaN   20.2   0.1750  55.500
# 53          9.4        1.0     0.666667   14.6   0.1800  25.235

# %%
df.vore.value_counts().plot.barh(color='skyblue');

# %% [markdown]
# Display PDF

# %%
IFrame('https://freemagazinepdf.com/wp-admin/admin-ajax.php?action=vkpd_file&id=308166&file=Love_Embroidery-_Issue10_UserUpload.Net.pdf', width=800, height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://freemagazinepdf.com/wp-admin/admin-ajax.php?action=vkpd_file&id=308166&file=Love_Embroidery-_Issue10_UserUpload.Net.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Youtube

# %%
YouTubeVideo('iheAKAkiAGg', 640, 360)

# %%
IFrame('https://txtlab.org/wp-content/uploads/2019/09/world.jpg', width=600, height=300)
# Out:
#         <iframe
#             width="600"
#             height="300"
#             src="https://txtlab.org/wp-content/uploads/2019/09/world.jpg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# HTML

# %%
s='''
<span style=color:red;font-size:150%>Hello world</span>

<span style=color:blue;font-size:150%>Ocean</span>

'''
HTML(s)
# Out:
# <span style=color:red;font-size:150%>Hello world</span>
#
# <span style=color:blue;font-size:150%>Ocean</span>

# %%
s='''
<div class="col-xs-12 col-md-6 col-sm-6 first-child">
        <div class="row">
            <div class="col-md-12 table-header-datetime">
                <div class="row">
                    * ข้อมูลล่าสุด : 02 มี.ค. 2564 13:12:57<br>
                    สถานะ : Intermission
                </div>
            </div>
        </div>
        <div class="row">
            <div class="graph-tunsan">
                <div class="row" style="margin-top: -15px;">
                    <div class="col-xs-4">
                        <select id="indexList" onchange="javascript:showGraph('set', this.value);">
                        
                            <option value="SET">SET</option>
                        
                            <option value="SET50">SET50</option>
                        
                            <option value="SET100">SET100</option>
                        
                            <option value="sSET">sSET</option>
                        
                            <option value="SETCLMV">SETCLMV</option>
                        
                            <option value="SETHD">SETHD</option>
                        
                            <option value="SETTHSI">SETTHSI</option>
                        
                            <option value="SETWB">SETWB</option>
                        
                        </select>
                    </div>
                </div>
                <div id="chartdiv" style="height: 160px; overflow: hidden; text-align: left;"><div style="overflow: hidden; position: relative; text-align: left; width: 284px; height: 160px; cursor: default;"><svg style="position: absolute; width: 284px; height: 160px; left: 0.5px; top: 0.100006px;" version="1.1"><g><path cs="100,100" d="M0.5,0.5 L283.5,0.5 L283.5,159.5 L0.5,159.5 Z" fill="#FFFFFF" stroke="#000000" fill-opacity="0" stroke-width="1" stroke-opacity="0"></path><path cs="100,100" d="M0.5,0.5 L204.5,0.5 L204.5,105.5 L0.5,105.5 Z" fill="#FFFFFF" stroke="#000000" fill-opacity="0" stroke-width="1" stroke-opacity="0" transform="translate(60,20)"></path></g><g><g transform="translate(60,20)"><g><path cs="100,100" d="M0.5,0.5 L0.5,5.5" fill="none" stroke-width="1" stroke-opacity="1" stroke="#000000" transform="translate(0,104)"></path><path cs="100,100" d="M0.5,104.5 L0.5,104.5 L0.5,0.5" fill="none" stroke-width="1" stroke-opacity="0.15" stroke="#000000"></path></g><g><path cs="100,100" d="M75.5,0.5 L75.5,5.5" fill="none" stroke-width="1" stroke-opacity="1" stroke="#000000" transform="translate(0,104)"></path><path cs="100,100" d="M75.5,104.5 L75.5,104.5 L75.5,0.5" fill="none" stroke-width="1" stroke-opacity="0.15" stroke="#000000"></path></g><g><path cs="100,100" d="M150.5,0.5 L150.5,5.5" fill="none" stroke-width="1" stroke-opacity="1" stroke="#000000" transform="translate(0,104)"></path><path cs="100,100" d="M150.5,104.5 L150.5,104.5 L150.5,0.5" fill="none" stroke-width="1" stroke-opacity="0.15" stroke="#000000"></path></g></g><g transform="translate(60,20)" visibility="visible"><g><path cs="100,100" d="M0.5,104.5 L5.5,104.5" fill="none" stroke-width="1" stroke-opacity="1" stroke="#000000" transform="translate(-6,0)"></path><path cs="100,100" d="M0.5,104.5 L0.5,104.5 L203.5,104.5" fill="none" stroke-width="1" stroke-opacity="0.15" stroke="#000000"></path></g><g><path cs="100,100" d="M0.5,52.5 L5.5,52.5" fill="none" stroke-width="1" stroke-opacity="1" stroke="#000000" transform="translate(-6,0)"></path><path cs="100,100" d="M0.5,52.5 L0.5,52.5 L203.5,52.5" fill="none" stroke-width="1" stroke-opacity="0.15" stroke="#000000"></path></g><g><path cs="100,100" d="M0.5,0.5 L5.5,0.5" fill="none" stroke-width="1" stroke-opacity="1" stroke="#000000" transform="translate(-6,0)"></path><path cs="100,100" d="M0.5,0.5 L0.5,0.5 L203.5,0.5" fill="none" stroke-width="1" stroke-opacity="0.15" stroke="#000000"></path></g></g></g><g></g><g></g><g></g><g><g transform="translate(60,20)"><g clip-path="url(#AmChartsEl-10)"><path cs="100,100" d="M2.5,94.5 L2.5,94.5 L3.5,94.5 L3.5,94.5 L4.5,94.5 L5.5,63.5 L5.5,52.5 L6.5,45.5 L6.5,61.5 L7.5,59.5 L8.5,54.5 L8.5,79.5 L9.5,75.5 L9.5,70.5 L10.5,65.5 L11.5,54.5 L11.5,53.5 L12.5,54.5 L12.5,42.5 L13.5,49.5 L14.5,48.5 L14.5,45.5 L15.5,41.5 L15.5,49.5 L16.5,39.5 L17.5,39.5 L17.5,38.5 L18.5,34.5 L18.5,36.5 L19.5,46.5 L20.5,55.5 L20.5,59.5 L21.5,58.5 L21.5,77.5 L22.5,77.5 L23.5,80.5 L23.5,77.5 L24.5,83.5 L24.5,83.5 L25.5,70.5 L26.5,78.5 L26.5,87.5 L27.5,83.5 L27.5,71.5 L28.5,67.5 L29.5,77.5 L29.5,81.5 L30.5,74.5 L30.5,83.5 L31.5,75.5 L32.5,75.5 L32.5,74.5 L33.5,78.5 L33.5,90.5 L34.5,81.5 L35.5,79.5 L35.5,90.5 L36.5,92.5 L36.5,74.5 L37.5,69.5 L38.5,61.5 L38.5,68.5 L39.5,70.5 L39.5,63.5 L40.5,61.5 L41.5,58.5 L41.5,68.5 L42.5,58.5 L42.5,60.5 L43.5,62.5 L44.5,61.5 L44.5,64.5 L45.5,65.5 L45.5,58.5 L46.5,58.5 L47.5,59.5 L47.5,55.5 L48.5,60.5 L48.5,64.5 L49.5,61.5 L50.5,62.5 L50.5,58.5 L51.5,65.5 L52.5,65.5 L52.5,65.5 L53.5,69.5 L53.5,67.5 L54.5,67.5 L55.5,66.5 L55.5,68.5 L56.5,62.5 L56.5,60.5 L57.5,58.5 L58.5,60.5 L58.5,63.5 L59.5,61.5 L59.5,55.5 L60.5,69.5 L61.5,58.5 L61.5,54.5 L62.5,50.5 L62.5,54.5 L63.5,51.5 L64.5,58.5 L64.5,56.5 L65.5,57.5 L65.5,53.5 L66.5,55.5 L67.5,34.5 L67.5,58.5 L68.5,53.5 L68.5,42.5 L69.5,46.5 L70.5,41.5 L70.5,51.5 L71.5,44.5 L71.5,41.5 L72.5,27.5 L73.5,22.5 L73.5,31.5 L74.5,28.5 L74.5,29.5 L75.5,20.5 L76.5,36.5 L76.5,32.5 L77.5,7.5 L77.5,27.5 L78.5,19.5 L79.5,21.5 L79.5,20.5 L80.5,22.5 L80.5,25.5 L81.5,30.5 L82.5,39.5 L82.5,39.5 L83.5,28.5 L83.5,31.5 L84.5,38.5 L85.5,30.5 L85.5,30.5 L86.5,30.5 L86.5,27.5 L87.5,28.5 L88.5,37.5 L88.5,30.5 L89.5,38.5 L89.5,35.5 L90.5,31.5 L91.5,28.5 L91.5,33.5 L92.5,26.5 L92.5,35.5 L93.5,22.5 L94.5,34.5 L94.5,40.5 L95.5,43.5 L95.5,42.5 L96.5,45.5 L97.5,32.5 L97.5,41.5 L98.5,41.5 L98.5,41.5 L99.5,41.5 L100.5,41.5 L100.5,41.5 M0,0 L0,0" fill="none" stroke-width="2" stroke-opacity="1" stroke="#f9bb00"></path></g><g></g><clipPath id="AmChartsEl-10"><rect x="0" y="0" width="205" height="106" rx="0" ry="0" stroke-width="0"></rect></clipPath></g></g><g clip-path="url(#AmChartsEl-9)"></g><g><g transform="translate(60,20)"><text y="5.5" fill="#000000" font-family="Verdana" font-size="11" text-anchor="middle" transform="translate(0,122)"><tspan y="5.5" x="0">SET Index</tspan></text><text y="5.5" fill="#000000" font-family="Verdana" font-size="11" text-anchor="middle" transform="translate(75,122)"><tspan y="5.5" x="0">11:52:00</tspan></text><text y="5.5" fill="#000000" font-family="Verdana" font-size="11" text-anchor="middle" transform="translate(150,122)"><tspan y="5.5" x="0">15:44:00</tspan></text></g><g transform="translate(60,20)" visibility="visible"><text y="5.5" fill="#000000" font-family="Verdana" font-size="11" text-anchor="end" transform="translate(-12,102)"><tspan y="5.5" x="0">1,500</tspan></text><text y="5.5" fill="#000000" font-family="Verdana" font-size="11" text-anchor="end" transform="translate(-12,50)"><tspan y="5.5" x="0">1,505</tspan></text><text y="5.5" fill="#000000" font-family="Verdana" font-size="11" text-anchor="end" transform="translate(-12,-2)"><tspan y="5.5" x="0">1,510</tspan></text></g></g><g><path cs="100,100" d="M0.5,0.5 L203.5,0.5" fill="none" stroke-width="1" stroke-opacity="1" stroke="#000000" transform="translate(60,124)"></path><path cs="100,100" d="M0.5,0.5 L0.5,104.5" fill="none" stroke-width="1" stroke-opacity="1" stroke="#000000" transform="translate(60,20)" visibility="visible"></path></g><g><g transform="translate(60,20)" visibility="hidden"><path cs="100,100" d="M0.5,0.5 L0.5,0.5 L0.5,104.5" fill="none" stroke-width="1" stroke-opacity="1" stroke="#CC0000" visibility="hidden" transform="translate(191,0)"></path></g></g><g></g><g><g transform="translate(60,20)"></g></g><g><g></g></g><g id="balloons"></g><g><g transform="translate(173,20)" visibility="hidden"><rect x="0.5" y="0.5" width="91" height="28" rx="0" ry="0" stroke-width="0" fill="#b2e1ff" stroke="#b2e1ff" fill-opacity="1" stroke-opacity="1" visibility="hidden"></rect><text y="5.5" fill="#000000" font-family="Verdana" font-size="11" text-anchor="start" transform="translate(29,13)"><tspan y="5.5" x="0">Show all</tspan></text></g></g><g></g><clipPath id="AmChartsEl-9"><rect x="60" y="20" width="204" height="105" rx="0" ry="0" stroke-width="0"></rect></clipPath></svg></div></div>
            </div>
        </div>
        <div class="row">
            <table class="table table-hover table-set col-3-center table-set-border-yellow">
                <thead>
                <tr>
                    <th></th>
                    <th><strong>ล่าสุด</strong></th>
                    <th><strong>เปลี่ยนแปลง</strong></th>
                    <th><strong>มูลค่า<br>(ลบ.)</strong></th>
                </tr>
                </thead>
                <tbody>
                
                    <tr>
                        <td>
                            
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/marketsummary.do?language=th&amp;country=TH" target="_blank">SET</a>
                                
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                1,506.06
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+5.14</td>
                        <td style="text-align: right;">48,641.03</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET50&amp;language=th&amp;country=TH" target="_blank">SET50</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                935.50
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+2.56</td>
                        <td style="text-align: right;">23,876.03</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET100&amp;language=th&amp;country=TH" target="_blank">SET100</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                2,116.83
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+4.96</td>
                        <td style="text-align: right;">34,537.25</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=sSET&amp;language=th&amp;country=TH" target="_blank">sSET</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                780.93
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+8.29</td>
                        <td style="text-align: right;">4,223.23</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETCLMV&amp;language=th&amp;country=TH" target="_blank">SETCLMV</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                991.59
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+0.24</td>
                        <td style="text-align: right;">12,142.64</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETHD&amp;language=th&amp;country=TH" target="_blank">SETHD</a>
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                1,097.96
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-0.51</td>
                        <td style="text-align: right;">9,255.86</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETTHSI&amp;language=th&amp;country=TH" target="_blank">SETTHSI</a>
                            
                        </td>
                        
                            
                            
                                
                                
                                
                            
                            
                        
                        <td style="text-align: right;" class="set-color-red"><i class="fa fa-caret-down"></i>
                            
                                
                                954.80
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-red">-0.37</td>
                        <td style="text-align: right;">23,640.84</td>
                    </tr>
                
                    <tr>
                        <td>
                            
                                
                                <a class="blacklink-u" href="https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SETWB&amp;language=th&amp;country=TH" target="_blank">SETWB</a>
                            
                        </td>
                        
                            
                                
                                
                                
                            
                            
                            
                        
                        <td style="text-align: right;" class="set-color-green"><i class="fa fa-caret-up"></i>
                            
                                
                                927.82
                                
                            
                        </td>
                        <td style="text-align: right;" class="set-color-green">+2.91</td>
                        <td style="text-align: right;">8,286.07</td>
                    </tr>
                
                </tbody>
            </table>
        </div>
        <div class="row remark-content" style="margin-top:0px">* ข้อมูลเพื่อการศึกษาหรือใช้งานส่วนบุคคลเท่านั้น ไม่ใช่เพื่อประกอบการซื้อขายหลักทรัพย์</div>
    </div>
'''
HTML(s)
# Out:
# <div class="col-xs-12 col-md-6 col-sm-6 first-child">
#         <div class="row">
#             <div class="col-md-12 table-header-datetime">
#                 <div class="row">
#                     * ข้อมูลล่าสุด : 02 มี.ค. 2564 13:12:57<br>
#                     สถานะ : Intermission
#                 </div>
#             </div>
#         </div>
#         <div class="row">
#             <div class="graph-tunsan">
#                 <div class="row" style="margin-top: -15px;">
#                     <div class="col-xs-4">
#                         <select id="indexList" onchange="javascript:showGraph('set', this.value);">
#
#                             <option value="SET">SET</option>
#
#                             <option value="SET50">SET50</option>
#
#                             <option value="SET100">SET100</option>
#
#                             <option value="sSET">sSET</option>
#
#                             <option value="SETCLMV">SETCLMV</option>
#
# ...
