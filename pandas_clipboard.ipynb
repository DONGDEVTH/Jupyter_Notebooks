# %%
import pandas as pd

# %% [markdown]
# ## copy data from Excel

# %%
df=pd.read_clipboard()
df
# Out:
#          Argentina        75    18.9  4.0    14.2  -25.0
# 0        Australia      5.90     1.3  4.7     1.1  -10.9
# 1           Brazil     16.50     3.2  5.1     3.1   -3.2
# 2          Britain      3.19     0.7  4.4     0.6  -16.4
# 3           Canada      6.55     1.2  5.3     1.2   -0.4
# 4            Chile   2600.00   605.9  4.3   492.4  -18.7
# 5            China     20.40     6.4  3.2     3.9  -39.9
# 6         Colombia  10900.00  2844.1  3.8  2064.4  -27.4
# 7       Costa Rica   2290.00   568.5  4.0   433.7  -23.7
# 8   Czech Republic     79.00    20.7  3.8    15.0  -27.9
# 9          Denmark     30.00     6.1  4.9     5.7   -6.6
# 10           Egypt     34.21    17.7  1.9     6.5  -63.4
# 11       Euro area      3.95     0.8  4.8     0.7   -8.4
# 12       Hong Kong     20.50     7.8  2.6     3.9  -50.3
# 13         Hungary    864.00   252.1  3.4   163.6  -35.1

# %%
df=pd.read_clipboard(names=['empId', 'firstname', 'lastname', 'gender'])
df
# Out:
#                           empId  firstname  lastname  gender
# Argentina      75.00       18.9        4.0      14.2   -25.0
# Australia      5.90         1.3        4.7       1.1   -10.9
# Brazil         16.50        3.2        5.1       3.1    -3.2
# Britain        3.19         0.7        4.4       0.6   -16.4
# Canada         6.55         1.2        5.3       1.2    -0.4
# Chile          2600.00    605.9        4.3     492.4   -18.7
# China          20.40        6.4        3.2       3.9   -39.9
# Colombia       10900.00  2844.1        3.8    2064.4   -27.4
# Costa Rica     2290.00    568.5        4.0     433.7   -23.7
# Czech Republic 79.00       20.7        3.8      15.0   -27.9
# Denmark        30.00        6.1        4.9       5.7    -6.6
# Egypt          34.21       17.7        1.9       6.5   -63.4
# Euro area      3.95         0.8        4.8       0.7    -8.4
# Hong Kong      20.50        7.8        2.6       3.9   -50.3
# Hungary        864.00     252.1        3.4     163.6   -35.1

# %%
df=pd.read_clipboard(index_col=0, names=['empId', 'firstname', 'lastname', 'gender'])
df
# Out:
#                 firstname  lastname  gender
# empId
# Argentina           75.00      18.9     4.0
# Australia            5.90       1.3     4.7
# Brazil              16.50       3.2     5.1
# Britain              3.19       0.7     4.4
# Canada               6.55       1.2     5.3
# Chile             2600.00     605.9     4.3
# China               20.40       6.4     3.2
# Colombia         10900.00    2844.1     3.8
# Costa Rica        2290.00     568.5     4.0
# Czech Republic      79.00      20.7     3.8
# Denmark             30.00       6.1     4.9
# Egypt               34.21      17.7     1.9
# Euro area            3.95       0.8     4.8
# Hong Kong           20.50       7.8     2.6
# Hungary            864.00     252.1     3.4

# %% [markdown]
# ## copy data from CSV (Comma-Separated Values)

# %%
df=pd.read_clipboard(sep=',')
df
# Out:
#          Argentina        75    18.9  4.0
# 0        Australia      5.90     1.3  4.7
# 1           Brazil     16.50     3.2  5.1
# 2          Britain      3.19     0.7  4.4
# 3           Canada      6.55     1.2  5.3
# 4            Chile   2600.00   605.9  4.3
# 5            China     20.40     6.4  3.2
# 6         Colombia  10900.00  2844.1  3.8
# 7       Costa Rica   2290.00   568.5  4.0
# 8   Czech Republic     79.00    20.7  3.8
# 9          Denmark     30.00     6.1  4.9
# 10           Egypt     34.21    17.7  1.9
# 11       Euro area      3.95     0.8  4.8
# 12       Hong Kong     20.50     7.8  2.6
# 13         Hungary    864.00   252.1  3.4

# %% [markdown]
# ## copy data from TSV (Tab-Separated Values)

# %%
df=pd.read_clipboard(sep='\t')
df
# Out:
#          Argentina        75    18.9  4.0
# 0        Australia      5.90     1.3  4.7
# 1           Brazil     16.50     3.2  5.1
# 2          Britain      3.19     0.7  4.4
# 3           Canada      6.55     1.2  5.3
# 4            Chile   2600.00   605.9  4.3
# 5            China     20.40     6.4  3.2
# 6         Colombia  10900.00  2844.1  3.8
# 7       Costa Rica   2290.00   568.5  4.0
# 8   Czech Republic     79.00    20.7  3.8
# 9          Denmark     30.00     6.1  4.9
# 10           Egypt     34.21    17.7  1.9
# 11       Euro area      3.95     0.8  4.8
# 12       Hong Kong     20.50     7.8  2.6
# 13         Hungary    864.00   252.1  3.4

# %% [markdown]
# ## copy data from HTML Table

# %%
# https://finance.yahoo.com/quote/SCC.BK/history?p=SCC.BK
# didn't work on Microsoft Edge browser
df=pd.read_clipboard()
df
# Out:
#            Date   Open   High    Low  Close*  Adj Close**     Volume
# 0  Mar 05, 2021  369.0  372.0  367.0   368.0        368.0  3,247,300
# 1  Mar 04, 2021  370.0  373.0  370.0   370.0        370.0  2,060,200
# 2  Mar 03, 2021  368.0  373.0  367.0   373.0        373.0  2,097,400
# 3  Mar 02, 2021  369.0  369.0  365.0   366.0        366.0  1,863,000
# 4  Mar 01, 2021  365.0  373.0  364.0   366.0        366.0  2,535,800
# 5  Feb 25, 2021  369.0  372.0  366.0   366.0        366.0  3,169,900

# %%
# https://finance.yahoo.com/quote/SCC.BK/history?p=SCC.BK
# work with Chrome/Firefox
df=pd.read_clipboard(index_col=0, parse_dates=True)
df
# Out:
#              Open   High    Low  Close*  Adj Close**     Volume
# Date
# 2021-03-05  369.0  372.0  367.0   368.0        368.0  3,247,300
# 2021-03-04  370.0  373.0  370.0   370.0        370.0  2,060,200
# 2021-03-03  368.0  373.0  367.0   373.0        373.0  2,097,400
# 2021-03-02  369.0  369.0  365.0   366.0        366.0  1,863,000

# %%
# %matplotlib inline
df['Close*'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
