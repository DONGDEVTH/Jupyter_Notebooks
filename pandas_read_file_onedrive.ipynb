# %% [markdown]
# # read file from OneDrive

# %% [markdown]
# ---
# * author: Prasert Kanawattanachai
# * e-mail: prasert.k@chula.ac.th
# * [Chulalongkorn Business School, Thailand](https://www.cbs.chula.ac.th/en/home/)
# ---

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('vmH1c-uCCW4', width=720, height=405)

# %%
import pandas as pd
print(f'pandas version: {pd.__version__}')
# Out:
# pandas version: 1.1.3

# %%
str(pd.datetime.now())
# Out:
# <ipython-input-7-7dab5cbcd016>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   str(pd.datetime.now())
# '2021-03-07 14:56:13.608593'

# %% [markdown]
# ## read CSV

# %% [raw]
# <iframe src="https://onedrive.live.com/embed?cid=EA83D0DA458C57AF&resid=EA83D0DA458C57AF%21120&authkey=ABwjbJ92M-owApw" width="98" height="120" frameborder="0" scrolling="no"></iframe>

# %%
url='https://onedrive.live.com/download?cid=EA83D0DA458C57AF&resid=EA83D0DA458C57AF%21120&authkey=ABwjbJ92M-owApw'
df=pd.read_csv(url)
df.head()
# Out:
#                     Flavour  Calories  Total Fat (g)  Trans Fat (g)  \
# 0            Bananas Foster       160            8.0            0.2
# 1              Baseball Nut       160            9.0            0.2
# 2        Beavertails Pastry       170            9.0            0.3
# 3  Blackberry Frozen Yogurt       120            4.0            0.1
# 4    Blue Raspberry Sherbet       130            2.0            0.1
#
#    Carbohydrates (g)  Sugars (g)  Protein (g)
# 0                 20          16          2.0
# 1                 19          13          3.0
# 2                 21          15          3.0
# 3                 17          16          3.0
# 4                 26          20          2.0

# %% [markdown]
# ## read TSV

# %% [raw]
# <iframe src="https://onedrive.live.com/embed?cid=EA83D0DA458C57AF&resid=EA83D0DA458C57AF%21117&authkey=AAHWJa9ZdLY4RO0" width="98" height="120" frameborder="0" scrolling="no"></iframe>

# %%
url='https://onedrive.live.com/download?cid=EA83D0DA458C57AF&resid=EA83D0DA458C57AF%21117&authkey=AAHWJa9ZdLY4RO0'
df=pd.read_csv(url, sep='\t')
df.head()
# Out:
#   p_id           name       name_en region   area_km2
# 0   กจ      กาญจนบุรี  Kanchanaburi      C  19483.148
# 1  กทม  กรุงเทพมหานคร       Bangkok      C   1568.737
# 2   จบ       จันทบุรี   Chanthaburi      C   6338.000
# 3   ฉช     ฉะเชิงเทรา  Chachoengsao      C   5351.000
# 4   ชน         ชัยนาท       Chainat      C   2469.746

# %% [markdown]
# ## read Excel

# %% [raw]
# <iframe src="https://onedrive.live.com/embed?cid=EA83D0DA458C57AF&resid=EA83D0DA458C57AF%21109&authkey=AKLyUafXPnHrlMY&em=2" width="402" height="346" frameborder="0" scrolling="no"></iframe>

# %%
url='https://onedrive.live.com/download?cid=EA83D0DA458C57AF&resid=EA83D0DA458C57AF%21109&authkey=AKLyUafXPnHrlMY'
df=pd.read_excel(url)
df.head()
# Out:
#    Rank    Country  Maths
# 0     1  Singapore    564
# 1     2  Hong Kong    548
# 2     3      Macau    544
# 3     4     Taiwan    542
# 4     5      Japan    532
